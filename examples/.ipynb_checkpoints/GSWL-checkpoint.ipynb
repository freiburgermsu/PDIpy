# %% [markdown]
# # Single cell

# %%
from scipy.constants import minute, milli
import os
# %run ../pdipy/core.py

solution_dimensions = {  # https://www.eppendorf.com/product-media/doc/en/90676/Eppendorf_Consumables_Technical-data_Cell-Culture-Plate-24-Well.pdf
    'surface area (m^2)': 16.2*milli,
    'solution_depth (m)': 17*milli,
    'solution_volume (m^3)': None
}

pdi = PDIBacterialPkg(verbose = True, jupyter = True)
pdi.define_system(surface_system = True, individual_cell = True, solution_dimensions = solution_dimensions)
pdi.define_bacterium(bacterial_specie = 'Saureus')
pdi.define_photosensitizer(photosensitizer = 'A3B_4Zn')
pdi.define_light(light_source = 'LED', lux = 26400,)
pdi.singlet_oxygen_calculations(timestep = 10, total_time = 500)
pdi.kinetic_calculation()
processed_data = pdi.export()

# %matplotlib inline

# %% [markdown]
# # Solution system

# %%
from scipy.constants import minute, micro, liter
import os
# %run ../pdipy/core.py

solution_dimensions = {  # https://www.eppendorf.com/product-media/doc/en/90676/Eppendorf_Consumables_Technical-data_Cell-Culture-Plate-24-Well.pdf
    'surface_area (m^2)': 16.2*milli,
    'solution_depth (m)': None,
    'solution_volume (m^3)': 200 *micro*liter
}

pdi = PDIBacterialPkg(verbose = True, jupyter = True)
pdi.define_system(surface_system = False, solution_dimensions = solution_dimensions)
pdi.define_bacterium(bacterial_specie = 'Saureus')
pdi.define_photosensitizer(photosensitizer_molar = 1*micro, photosensitizer = 'A3B_4Zn')
pdi.define_light(light_source = 'LED', lux = 26400,)
pdi.singlet_oxygen_calculations(timestep = 10, total_time = 500)
pdi.kinetic_calculation()
processed_data = pdi.export()

# %matplotlib inline
# Out:
# 2e-07
# None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-b1cccf3d3d88> in <module>
#      12 pdi.define_system(surface_system = False, solution_dimensions = solution_dimensions)
#      13 pdi.define_bacterium(bacterial_specie = 'Saureus')
# ---> 14 pdi.define_photosensitizer(photosensitizer = 'A3B_4Zn')
#      15 pdi.define_light(light_source = 'LED', lux = 26400,)
#      16 pdi.singlet_oxygen_calculations(timestep = 10, total_time = 500)
#
# ~\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PDIpy\PDIpy\pdipy\core.py in define_photosensitizer(self, photosensitizer_molar, photosensitizer, molecular_proportion)
#     143             print(self.parameters['solution_volume (m^3)'])
#     144             print(self.parameters['photosensitizer_molar'])
# --> 145             self.variables['photosensitizers'] = (self.parameters['photosensitizer_molar']*N_A) * (self.parameters['solution_volume (m^3)']/liter)
#     146         else:
#     147             self.variables['photosensitizers'] = self.parameters['photosensitizer (g/m^2)'] / (self.photosensitizer['mw']['value']/N_A) * self.parameters['surface_area (m^2)']
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'float'

# %% [markdown]
# # Surface system

# %%
from scipy.constants import minute
import os
# %run ../pdipy/core.py

pdi = PDIBacterialPkg(verbose = True, jupyter = True)
pdi.define_system(surface_system = True)
pdi.define_bacterium(bacterial_specie = 'Saureus')
pdi.define_photosensitizer(photosensitizer = 'A3B_4Zn')
pdi.define_light(light_source = 'LED', lux = 26400,)
pdi.singlet_oxygen_calculations(timestep = 10, total_time = 500)
pdi.kinetic_calculation()
processed_data = pdi.export()

# %matplotlib inline
# Out:
# 4.2516400053194203e-11
# 5.997473236245768e-13
# The tetrapyrrole length is 6.1E-10 meters
# The benzyl extension is 6.1E-10 meters
# The diazirine is 7.2E-10 meters
#
# The molecular length is 3.3E-9 meters
# The molecular volume is 1.2E-27 cubic meters
# The volume proportion of 3.7E16 photosensitizers is 7.1E1
#
# ('photons per timestep: ', 2.1128599811696933)
# ('molecular oxygen molecules: ', '2.8E-7')
# ('effective excitation watts: ', '8.6E2')
# // Created by libAntimony v2.12.0.3
# model *pdipy_oxidation()
#
#   // Compartments and Species:
#   species ps, e_ps, b_ps, mo, so, fa, o_fa;
#
#   // Assignment Rules:
#   oxidation := o_fa/(o_fa + fa);
#
#   // Reactions:
#   _J0: ps -> e_ps; 20000000000000*1*0.6*ps - 666666666.666667*e_ps;
#   _J1: ps => b_ps; 0.000270211764705882*ps;
#   _J2: e_ps + mo -> so + ps; 0.48*2000000*e_ps*mo - 97087.0958345471*so;
#   _J3: so + fa => o_fa + mo; 651.89668*so*fa;
#
#   // Species initializations:
#   ps = 0.00563514941195659;
#   e_ps = 101.432689415219;
#   b_ps = 0.0456907971583181;
#   mo = 2.80148545627009e-10;
#   so = 2.80980398724896e-07;
#   fa = 3.83975153497509e-06;
#   o_fa = 0.000931105265889473;
#
#   // Variable initializations:
#   o_eps = 0;
#
#   // Other declarations:
#   var oxidation;
#   const o_eps;
# end
#
# ('\nCurrent integrator:', '\n', < roadrunner.Integrator() "cvode" 'relative_tolerance': 0.000001, 'absolute_tolerance': 0.000000000001, 'stiff': True, 'maximum_bdf_order': 5, 'maximum_adams_order': 12, 'maximum_num_steps': 20000, 'maximum_time_step': 0, 'minimum_time_step': 0, 'initial_time_step': 0, 'multiple_steps': False, 'variable_step_size': False, 'max_output_rows': 100000 >
# )

# 0   C:\Users\Andrew Freiburger\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PDIpy\PDIpy\examples\2021-12-13-PDIpy-A3B_4Zn-Saureus
# 1                                                                                                                                            0.000000
# 2                                                                                                                                                   5
# 3                                       C:\Users\Andrew Freiburger\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PDIpy\PDIpy\pdipy
# 4                                                                                                                                               water
# 5                                                                                                                                            0.090000
# 6                                                                                                                                            1.911345
# 7                                                                                                                                            0.000191
# 8                                                                                                                                            0.470873
# 9                                                                                                                                             Saureus
# 10                                                                                                                                            A3B_4Zn
# 11                                                                                                {'upper': 4.3e-07, 'lower': 4.0000000000000003e-07}
# 12                                                                                                              {'upper': 6.25e-07, 'lower': 5.3e-07}
# 13                                                                                                                                           0.000000
# 14                                                                                                                                           0.000000
# 15                                                                                                                                         101.484015
# 16                                                                                                               {'upper': 7.8e-07, 'lower': 3.9e-07}
# 17                                                                                                                                           0.500000
# 18                                                                                                                                        2968.206307
# 19                                                                                                                                                  0
# 20                                                                                                                                       30000.000000
# 21                                                                                                                                         600.000000
#                      variable  \
# 0             simulation_path
# 1                 fa_g/L_conc
# 2                    fa_molar
# 3     center_porphyrin_length
# 4               sp2_extension
# 5               sp3_diazirine
# 6        linked_sp3_diazirine
# 7            photosensitizers
# 8      molecular_volume (m^3)
# 9           volume_proportion
# 10  photon_moles_per_timestep
# 11         dissolved_mo_molar
# 12        e_ps_decay_time (s)
# 13          ps_excitation (s)
# 14          hv_photobleaching
# 15                      so_qy
# 16   e_ps_charge_transfer (s)
# 17          so_decay_time (s)
# 18           so_rise_time (s)
# 19                       k_fa
#
#                                                                                                                                                 value
# 0   C:\Users\Andrew Freiburger\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PDIpy\PDIpy\examples\2021-12-13-PDIpy-A3B_4Zn-Saureus
# 1                                                                                                                                            0.847720
# 2                                                                                                                                            0.000935
# 3                                                                                                                                            0.000000
# 4                                                                                                                                            0.000000
# 5                                                                                                                                            0.000000
# 6                                                                                                                                            0.000000
# 7                                                                                                                            36653619181328312.000000
# 8                                                                                                                                            0.000000
# 9                                                                                                                                           70.890521
# 10                                                                                                                                           2.112860
# 11                                                                                                                                           0.000000
# 12                                                                                                                                           0.000000
# 13                                                                                                                                           0.000000
# 14                                                                                                                                           0.000270
# 15                                                                                                                                           0.480000
# 16                                                                                                                                           0.000001
# 17                                                                                                                                           0.000010
# 18                                                                                                                                           0.000002
# 19                                                                                                                                         651.896680

# %% [markdown]
# # Surface biofilm system

# %%
from scipy.constants import minute
import os
# %run ../pdipy/core.py

pdi = PDIBacterialPkg(verbose = True, jupyter = True)
pdi.define_system(surface_system = True)
pdi.define_bacterium(bacterial_specie = 'Saureus')
pdi.define_photosensitizer(photosensitizer = 'A3B_4Zn')
pdi.define_light(light_source = 'LED', lux = 26400,)
pdi.singlet_oxygen_calculations(timestep = 20, total_time = 800)
pdi.cytoplasmic_membrane()
raw_data = pdi.kinetic_calculation()
processed_data = pdi.export(excitation_proportion = True)

# %matplotlib inline
# Out:
# 1.4172133351064733e-10
# 5.997473236245768e-13
# The tetrapyrrole is 6.1E-10 meters
# The benzyl extension is 6.1E-10 meters
# The diazirine is 7.2E-10 meters
# Solution depth is not calculated for surface systems
# The molecular length is 3.3E-9 meters
# The molecular volume is 1.2E-27 cubic meters
# The photosensitizer volume proportion is 2.4E2
# The photosensitizer area proportion is 3.5E3
# e_ps times greater than the photosensitizer molar 1.7710975704625804
# ('photons per timestep: ', 4.225719962339387)
# ('molecular oxygen molecules: ', '2.8E-7')
# ('effective excitation watts: ', '8.6E2')
# // Created by libAntimony v2.12.0.3
# model *pdipy_oxidation()
#
#   // Compartments and Species:
#   species ps, e_ps, b_ps, mo, so, fa, o_fa;
#
#   // Assignment Rules:
#   oxidation := o_fa/(o_fa + fa);
#
#   // Reactions:
#   _J0: ps -> e_ps; 20000000000000*ps - 666666666.666667*e_ps;
#   _J1: ps => b_ps; 0.000270211764705882*ps;
#   _J2: e_ps + mo -> so + ps; 0.48*2000000*e_ps*mo - 97087.0958345471*so;
#   _J3: so + fa => o_fa + mo; 618.206041660442*so*fa;
#
#   // Species initializations:
#   ps = 0.0112707521779258;
#   e_ps = 338.122565337774;
#   b_ps = 0.146215116011619;
#   mo = 8.40998191810324e-11;
#   so = 2.81176447451342e-07;
#   fa = 2.39150369583496e-07;
#   o_fa = 0.00100507807266746;
#
#   // Variable initializations:
#   o_eps = 0;
#
#   // Other declarations:
#   var oxidation;
#   const o_eps;
# end
#
# ('\nCurrent integrator:', '\n', < roadrunner.Integrator() "cvode" 'relative_tolerance': 0.000001, 'absolute_tolerance': 0.000000000001, 'stiff': True, 'maximum_bdf_order': 5, 'maximum_adams_order': 12, 'maximum_num_steps': 20000, 'maximum_time_step': 0, 'minimum_time_step': 0, 'initial_time_step': 0, 'multiple_steps': False, 'variable_step_size': False, 'max_output_rows': 100000 >
# )
# 45538.461538    0.011271  338.130062  0.138718  8.409796e-11  2.811764e-07
# 46769.230769    0.011271  338.126314  0.142467  8.409889e-11  2.811764e-07
# 48000.000000    0.011271  338.122565  0.146215  8.409982e-11  2.811764e-07
#
#                       [fa]     [ofa]
# Time (s)
# 0.000000      1.005317e-03  0.000000
# 1230.769231   8.116910e-04  0.000194
# 2461.538462   6.553558e-04  0.000350
# 3692.307692   5.291310e-04  0.000476
# 4923.076923   4.272179e-04  0.000578
# 6153.846154   3.449338e-04  0.000660
# 7384.615385   2.784979e-04  0.000727
# 8615.384615   2.248579e-04  0.000780
# 9846.153846   1.815493e-04  0.000824
# 11076.923077  1.465820e-04  0.000859
# 12307.692308  1.183496e-04  0.000887
# 13538.461538  9.555495e-05  0.000910
# 14769.230769  7.715061e-05  0.000928
# 16000.000000  6.229106e-05  0.000943
# 17230.769231  5.029350e-05  0.000955
# 18461.538462  4.060674e-05  0.000965
# 19692.307692  3.278570e-05  0.000973
# 20923.076923  2.647102e-05  0.000979
# 22153.846154  2.137257e-05  0.000984
# 23384.615385  1.725612e-05  0.000988
# 24615.384615  1.393251e-05  0.000991
# 25846.153846  1.124904e-05  0.000994
# 27076.923077  9.082426e-06  0.000996
# 28307.692308  7.333107e-06  0.000998
# 29538.461538  5.920717e-06  0.000999
# 30769.230769  4.780360e-06  0.001001
# 32000.000000  3.859640e-06  0.001001
# 33230.769231  3.116256e-06  0.001002
# 34461.538462  2.516050e-06  0.001003
# 35692.307692  2.031447e-06  0.001003
# 36923.076923  1.640181e-06  0.001004
# 38153.846154  1.324274e-06  0.001004
# 39384.615385  1.069213e-06  0.001004
# 40615.384615  8.632778e-07  0.001004
# 41846.153846  6.970060e-07  0.001005
# 43076.923077  5.627555e-07  0.001005
# 44307.692308  4.543648e-07  0.001005
# 45538.461538  3.668547e-07  0.001005
# 46769.230769  2.961986e-07  0.001005
# 48000.000000  2.391504e-07  0.001005
#                                  parameter  \
# 0                          simulation_path
# 1   singlet_oxygen_diffusion_distance (nm)
# 2                          oxidation_angle
# 3                                root_path
# 4                                   medium
# 5              photosensitizer_mg_per_disc
# 6                             cm2_per_disc
# 7                       surface_area (m^2)
# 8            photosensitizer_mg_per_sqr_cm
# 9                         bacterial_specie
# 10               photosensitizer_selection
# 11                               soret (m)
# 12                                   q (m)
# 13                        atomic_thickness
# 14                   solution_volume (m^3)
# 15                   photosensitizer_molar
# 16                            visible (nm)
# 17                      visible_proportion
# 18                                   watts
# 19                            initial_time
# 20                          total_time (s)
# 21                            timestep (s)
#
#                                                                                                                                                   value
# 0   C:\Users\Andrew Freiburger\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PDIpy\PDIpy\examples\2021-12-10-PDIpy-A3B_4Zn-Saureus-1
# 1                                                                                                                                              0.000000
# 2                                                                                                                                                     5
# 3                                         C:\Users\Andrew Freiburger\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PDIpy\PDIpy\pdipy
# 4                                                                                                                                                 water
# 5                                                                                                                                              0.300000
# 6                                                                                                                                              1.911345
# 7                                                                                                                                              0.000191
# 8                                                                                                                                              0.156958
# 9                                                                                                                                               Saureus
# 10                                                                                                                                              A3B_4Zn
# 11                                                                                                  {'upper': 4.3e-07, 'lower': 4.0000000000000003e-07}
# 12                                                                                                                {'upper': 6.25e-07, 'lower': 5.3e-07}
# 13                                                                                                                                             0.000000
# 14                                                                                                                                             0.000000
# 15                                                                                                                                           338.280051
# 16                                                                                                                 {'upper': 7.8e-07, 'lower': 3.9e-07}
# 17                                                                                                                                             0.500000
# 18                                                                                                                                          2968.206307
# 19                                                                                                                                                    0
# 20                                                                                                                                         48000.000000
# 21                                                                                                                                          1200.000000
#                      variable  \
# 0             simulation_path
# 1     center_porphyrin_length
# 2               sp2_extension
# 3               sp3_diazirine
# 4        linked_sp3_diazirine
# 5            photosensitizers
# 6      molecular_volume (m^3)
# 7           volume_proportion
# 8             area_proportion
# 9     photon_moles_per_second
# 10  photon_moles_per_timestep
# 11         dissolved_mo_molar
# 12            e_ps_calculated
# 13                      so_qy
# 14          so_decay_time (s)
# 15           so_rise_time (s)
# 16   e_ps_charge_transfer (s)
# 17        e_ps_decay_time (s)
# 18          ps_excitation (s)
# 19          hv_photobleaching
# 20                fa_g/L_conc
# 21                   fa_molar
# 22                       k_fa
#
#                                                                                                                                                   value
# 0   C:\Users\Andrew Freiburger\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PDIpy\PDIpy\examples\2021-12-10-PDIpy-A3B_4Zn-Saureus-1
# 1                                                                                                                                              0.000000
# 2                                                                                                                                              0.000000
# 3                                                                                                                                              0.000000
# 4                                                                                                                                              0.000000
# 5                                                                                                                             122178730604427696.000000
# 6                                                                                                                                              0.000000
# 7                                                                                                                                            236.301736
# 8                                                                                                                                           3458.115578
# 9                                                                                                                                              0.003521
# 10                                                                                                                                             4.225720
# 11                                                                                                                                             0.000000
# 12                                                                                                                                           338.280051
# 13                                                                                                                                             0.480000
# 14                                                                                                                                             0.000010
# 15                                                                                                                                             0.000002
# 16                                                                                                                                             0.000001
# 17                                                                                                                                             0.000000
# 18                                                                                                                                             0.000000
# 19                                                                                                                                             0.000270
# 20                                                                                                                                           911.526882
# 21                                                                                                                                             0.001005
# 22                                                                                                                                           618.206042

# %% [markdown]
# ## Processing the raw data

# %%
display(processed_data)

target_reduction = 0.98
for index, point in processed_data.iterrows():
    if index > 6:
        print(point['oxidation_proportion'])
    if point['oxidation_proportion'] >= target_reduction:
        print('time to target (hr): ', index)
        break
# display(raw_data)
# Out:
#            oxidation_proportion
# time (hr)
# 0.000000               0.000000
# 0.170068               0.106085
# 0.340136               0.200916
# 0.510204               0.285687
# 0.680272               0.361465
# 0.850340               0.429205
# 1.020408               0.489759
# 1.190476               0.543889
# 1.360544               0.592277
# 1.530612               0.635532
# 1.700680               0.674197
# 1.870748               0.708760
# 2.040816               0.739656
# 2.210884               0.767274
# 2.380952               0.791963
# 2.551020               0.814033
# 2.721088               0.833761
# 2.891156               0.851396
# 3.061224               0.867160
# 3.231293               0.881252
# 3.401361               0.893850
# 3.571429               0.905111
# 3.741497               0.915177
# 3.911565               0.924175
# 4.081633               0.932219
# 4.251701               0.939409
# 4.421769               0.945837
# 4.591837               0.951583
# 4.761905               0.956720
# 4.931973               0.961311
# 5.102041               0.965415
# 5.272109               0.969084
# 5.442177               0.972364
# 5.612245               0.975296
# 5.782313               0.977916
# 5.952381               0.980259
# 6.122449               0.982353
# 6.292517               0.984225
# 6.462585               0.985899
# 6.632653               0.987395
# 6.802721               0.988732
# 6.972789               0.989927
# 7.142857               0.990996
# 7.312925               0.991951
# 7.482993               0.992805
# 7.653061               0.993568
# 7.823129               0.994251
# 7.993197               0.994860
# 8.163265               0.995406
# 8.333333               0.995893
# time to target (hr):  5.952380952380952
