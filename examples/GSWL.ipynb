# %% [markdown]
# # Define and execute the simulation

# %%
from scipy.constants import minute
import os
# %run ../pdipy/core.py

pdi = PDIBacterialPkg(verbose = True, jupyter = True)
pdi.define_system(surface_system = True)
pdi.define_bacterium(bacterial_specie = 'Saureus')
pdi.define_photosensitizer(photosensitizer = 'A3B_4Zn')
pdi.define_light(light_source = 'LED', lux = 26400,)
pdi.singlet_oxygen_calculations(timestep = 0.2, total_time = 10)
pdi.cytoplasmic_membrane()
pdi.kinetic_calculation()
pdi.export()

# %matplotlib inline
# Out:
# 1.4172133351064733e-10
# 5.997473236245768e-13
# The tetrapyrrole is 6.1E-10 meters
# The benzyl extension is 6.1E-10 meters
# The diazirine is 7.2E-10 meters
# Solution depth is not calculated for surface systems
# The molecular length is 3.3E-9 meters
# The molecular volume is 1.2E-27 cubic meters
# The photosensitizer volume proportion is 2.4E2
#
# ('photons per timestep: ', 0.04225719962339387)
# ('molecular oxygen molecules: ', '2.8E-7')
# ('effective excitation watts: ', '8.6E2')
# // Created by libAntimony v2.12.0.3
# model *pdipy_oxidation()
#
#   // Compartments and Species:
#   species ps, e_ps, b_ps, mo, so, fa, o_fa;
#
#   // Assignment Rules:
#   oxidation := o_fa/(o_fa + fa);
#
#   // Reactions:
#   _J0: ps -> e_ps; 20000000000000*1*0.6*ps - 666666666.666667*e_ps;
#   _J1: e_ps => b_ps; 0.000270211764705882*e_ps;
#   _J2: e_ps + mo -> so + ps; 0.48*2000000*e_ps*mo - 97087.0958345471*so;
#   _J3: so + fa => o_fa + mo; 246.112258064516*so*fa;
#
#   // Species initializations:
#   ps = 0.0159798653937345;
#   e_ps = 287.637577087221;
#   b_ps = 50.6264942529564;
#   mo = 9.8855490889404e-11;
#   so = 2.81161691779634e-07;
#   fa = 2.42254260599428e-06;
#   o_fa = 1.02700085915348e-07;
#
#   // Variable initializations:
#   o_eps = 0;
#
#   // Other declarations:
#   var oxidation;
#   const o_eps;
# end
#
# ('\nCurrent integrator:', '\n', < roadrunner.Integrator() "cvode" 'relative_tolerance': 0.000001, 'absolute_tolerance': 0.000000000001, 'stiff': True, 'maximum_bdf_order': 5, 'maximum_adams_order': 12, 'maximum_num_steps': 20000, 'maximum_time_step': 0, 'minimum_time_step': 0, 'initial_time_step': 0, 'multiple_steps': False, 'variable_step_size': False, 'max_output_rows': 100000 >
# )
#                   [ps]      [e_ps]     [b_ps]          [mo]          [so]  \
# Time (s)
# 0.000000    338.280051    0.000000   0.000000  2.812605e-07  0.000000e+00
# 12.244898     0.018730  337.143960   1.117361  8.434386e-11  2.811762e-07
# 24.489796     0.018668  336.030351   2.231032  8.462329e-11  2.811759e-07
# 36.734694     0.018607  334.920421   3.341024  8.490365e-11  2.811756e-07
# 48.979592     0.018545  333.814157   4.447349  8.518493e-11  2.811754e-07
# 61.224490     0.018484  332.711547   5.550020  8.546715e-11  2.811751e-07
# 73.469388     0.018423  331.612580   6.649049  8.575030e-11  2.811748e-07
# 85.714286     0.018362  330.517242   7.744447  8.603440e-11  2.811745e-07
# 97.959184     0.018301  329.425523   8.836226  8.631943e-11  2.811742e-07
# 110.204082    0.018241  328.337411   9.924399  8.660540e-11  2.811739e-07
# 122.448980    0.018181  327.252893  11.008978  8.689232e-11  2.811737e-07
# 134.693878    0.018121  326.171957  12.089974  8.718020e-11  2.811734e-07
# 146.938776    0.018061  325.094591  13.167399  8.746902e-11  2.811731e-07
# 159.183673    0.018001  324.020783  14.241267  8.775880e-11  2.811728e-07
# 171.428571    0.017942  322.950524  15.311585  8.804955e-11  2.811725e-07
# 183.673469    0.017882  321.883801  16.378368  8.834125e-11  2.811722e-07
# 195.918367    0.017823  320.820600  17.441628  8.863392e-11  2.811719e-07
# 208.163265    0.017764  319.760911  18.501376  8.892756e-11  2.811716e-07
# 220.408163    0.017706  318.704722  19.557624  8.922218e-11  2.811713e-07
# 232.653061    0.017647  317.652020  20.610383  8.951776e-11  2.811710e-07
# 244.897959    0.017589  316.602798  21.659664  8.981433e-11  2.811707e-07
# 195.918367  0.000002  3.400528e-08
# 208.163265  0.000002  3.611532e-08
# 220.408163  0.000002  3.822357e-08
# 232.653061  0.000002  4.033004e-08
# 244.897959  0.000002  4.243472e-08
# 257.142857  0.000002  4.453761e-08
# 269.387755  0.000002  4.663872e-08
# 281.632653  0.000002  4.873805e-08
# 293.877551  0.000002  5.083560e-08
# 306.122449  0.000002  5.293137e-08
# 318.367347  0.000002  5.502536e-08
# 330.612245  0.000002  5.711758e-08
# 342.857143  0.000002  5.920802e-08
# 355.102041  0.000002  6.129669e-08
# 367.346939  0.000002  6.338359e-08
# 379.591837  0.000002  6.546872e-08
# 391.836735  0.000002  6.755208e-08
# 404.081633  0.000002  6.963367e-08
# 416.326531  0.000002  7.171350e-08
# 428.571429  0.000002  7.379156e-08
# 440.816327  0.000002  7.586786e-08
# 453.061224  0.000002  7.794240e-08
# 465.306122  0.000002  8.001519e-08
# 477.551020  0.000002  8.208621e-08
# 489.795918  0.000002  8.415548e-08
# 502.040816  0.000002  8.622299e-08
# 514.285714  0.000002  8.828875e-08
# 526.530612  0.000002  9.035275e-08
# 538.775510  0.000002  9.241501e-08
# 551.020408  0.000002  9.447552e-08
# 563.265306  0.000002  9.653428e-08
# 575.510204  0.000002  9.859129e-08
# 587.755102  0.000002  1.006466e-07
# 600.000000  0.000002  1.027001e-07
#                                  parameter  \
# 0                          simulation_path
# 1   singlet_oxygen_diffusion_distance (nm)
# 2                          oxidation_angle
# 3                                root_path
# 4                                   medium
# 5              photosensitizer_mg_per_disc
# 6                             cm2_per_disc
# 7                       surface_area (m^2)
# 8                  photosensitizer (g/m^2)
# 9                         bacterial_specie
# 10               photosensitizer_selection
# 11                               soret (m)
# 12                                   q (m)
# 13                        atomic_thickness
# 14                   solution_volume (m^3)
# 15                   photosensitizer_molar
# 16                            visible (nm)
# 17                      visible_proportion
# 18                                   watts
# 19                            initial_time
# 20                          total_time (s)
# 21                            timestep (s)
#
#                                                                                                                                                   value
# 0   C:\Users\Andrew Freiburger\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PDIpy\PDIpy\examples\2021-12-12-PDIpy-A3B_4Zn-Saureus-1
# 1                                                                                                                                              0.000000
# 2                                                                                                                                                     5
# 3                                         C:\Users\Andrew Freiburger\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PDIpy\PDIpy\pdipy
# 4                                                                                                                                                 water
# 5                                                                                                                                              0.300000
# 6                                                                                                                                              1.911345
# 7                                                                                                                                              0.000191
# 8                                                                                                                                              1.569575
# 9                                                                                                                                               Saureus
# 10                                                                                                                                              A3B_4Zn
# 11                                                                                                  {'upper': 4.3e-07, 'lower': 4.0000000000000003e-07}
# 12                                                                                                                {'upper': 6.25e-07, 'lower': 5.3e-07}
# 13                                                                                                                                             0.000000
# 14                                                                                                                                             0.000000
# 15                                                                                                                                           338.280051
# 16                                                                                                                 {'upper': 7.8e-07, 'lower': 3.9e-07}
# 17                                                                                                                                             0.500000
# 18                                                                                                                                          2968.206307
# 19                                                                                                                                                    0
# 20                                                                                                                                           600.000000
# 21                                                                                                                                            12.000000
#                      variable  \
# 0             simulation_path
# 1     center_porphyrin_length
# 2               sp2_extension
# 3               sp3_diazirine
# 4        linked_sp3_diazirine
# 5            photosensitizers
# 6      molecular_volume (m^3)
# 7           volume_proportion
# 8   photon_moles_per_timestep
# 9          dissolved_mo_molar
# 10                fa_g/L_conc
# 11                   fa_molar
# 12        e_ps_decay_time (s)
# 13          ps_excitation (s)
# 14          hv_photobleaching
# 15                      so_qy
# 16   e_ps_charge_transfer (s)
# 17          so_decay_time (s)
# 18           so_rise_time (s)
# 19                       k_fa
#
#                                                                                                                                                   value
# 0   C:\Users\Andrew Freiburger\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PDIpy\PDIpy\examples\2021-12-12-PDIpy-A3B_4Zn-Saureus-1
# 1                                                                                                                                              0.000000
# 2                                                                                                                                              0.000000
# 3                                                                                                                                              0.000000
# 4                                                                                                                                              0.000000
# 5                                                                                                                             122178730604427696.000000
# 6                                                                                                                                              0.000000
# 7                                                                                                                                            236.301736
# 8                                                                                                                                              0.042257
# 9                                                                                                                                              0.000000
# 10                                                                                                                                             0.911527
# 11                                                                                                                                             0.001005
# 12                                                                                                                                             0.000000
# 13                                                                                                                                             0.000000
# 14                                                                                                                                             0.000270
# 15                                                                                                                                             0.480000
# 16                                                                                                                                             0.000001
# 17                                                                                                                                             0.000010
# 18                                                                                                                                             0.000002
# 19                                                                                                                                           246.112258

# %% [markdown]
# # Surface biofilm system

# %%
from scipy.constants import minute
import os
# %run ../pdipy/core.py

pdi = PDIBacterialPkg(verbose = True, jupyter = True)
pdi.define_system(surface_system = True)
pdi.define_bacterium(bacterial_specie = 'Saureus')
pdi.define_photosensitizer(photosensitizer = 'A3B_4Zn')
pdi.define_light(light_source = 'LED', lux = 26400,)
pdi.singlet_oxygen_calculations(timestep = 20, total_time = 800)
pdi.cytoplasmic_membrane()
raw_data = pdi.kinetic_calculation()
processed_data = pdi.export(excitation_proportion = True)

# %matplotlib inline
# Out:
# 1.4172133351064733e-10
# 5.997473236245768e-13
# The tetrapyrrole is 6.1E-10 meters
# The benzyl extension is 6.1E-10 meters
# The diazirine is 7.2E-10 meters
# Solution depth is not calculated for surface systems
# The molecular length is 3.3E-9 meters
# The molecular volume is 1.2E-27 cubic meters
# The photosensitizer volume proportion is 2.4E2
# The photosensitizer area proportion is 3.5E3
# e_ps times greater than the photosensitizer molar 1.7710975704625804
# ('photons per timestep: ', 4.225719962339387)
# ('molecular oxygen molecules: ', '2.8E-7')
# ('effective excitation watts: ', '8.6E2')
# // Created by libAntimony v2.12.0.3
# model *pdipy_oxidation()
#
#   // Compartments and Species:
#   species ps, e_ps, b_ps, mo, so, fa, o_fa;
#
#   // Assignment Rules:
#   oxidation := o_fa/(o_fa + fa);
#
#   // Reactions:
#   _J0: ps -> e_ps; 20000000000000*ps - 666666666.666667*e_ps;
#   _J1: ps => b_ps; 0.000270211764705882*ps;
#   _J2: e_ps + mo -> so + ps; 0.48*2000000*e_ps*mo - 97087.0958345471*so;
#   _J3: so + fa => o_fa + mo; 618.206041660442*so*fa;
#
#   // Species initializations:
#   ps = 0.0112707521779258;
#   e_ps = 338.122565337774;
#   b_ps = 0.146215116011619;
#   mo = 8.40998191810324e-11;
#   so = 2.81176447451342e-07;
#   fa = 2.39150369583496e-07;
#   o_fa = 0.00100507807266746;
#
#   // Variable initializations:
#   o_eps = 0;
#
#   // Other declarations:
#   var oxidation;
#   const o_eps;
# end
#
# ('\nCurrent integrator:', '\n', < roadrunner.Integrator() "cvode" 'relative_tolerance': 0.000001, 'absolute_tolerance': 0.000000000001, 'stiff': True, 'maximum_bdf_order': 5, 'maximum_adams_order': 12, 'maximum_num_steps': 20000, 'maximum_time_step': 0, 'minimum_time_step': 0, 'initial_time_step': 0, 'multiple_steps': False, 'variable_step_size': False, 'max_output_rows': 100000 >
# )
#                     [ps]      [e_ps]    [b_ps]          [mo]          [so]  \
# Time (s)
# 0.000000      338.280051    0.000000  0.000000  2.812605e-07  0.000000e+00
# 1230.769231     0.011276  338.265026  0.003750  8.406485e-11  2.811765e-07
# 2461.538462     0.011275  338.261276  0.007500  8.406569e-11  2.811765e-07
# 3692.307692     0.011275  338.257526  0.011250  8.406656e-11  2.811765e-07
# 2461.538462   6.553558e-04  0.000350
# 3692.307692   5.291310e-04  0.000476
# 4923.076923   4.272179e-04  0.000578
# 6153.846154   3.449338e-04  0.000660
# 7384.615385   2.784979e-04  0.000727
# 8615.384615   2.248579e-04  0.000780
# 9846.153846   1.815493e-04  0.000824
# 11076.923077  1.465820e-04  0.000859
# 12307.692308  1.183496e-04  0.000887
# 13538.461538  9.555495e-05  0.000910
# 14769.230769  7.715061e-05  0.000928
# 16000.000000  6.229106e-05  0.000943
# 17230.769231  5.029350e-05  0.000955
# 18461.538462  4.060674e-05  0.000965
# 19692.307692  3.278570e-05  0.000973
# 20923.076923  2.647102e-05  0.000979
# 22153.846154  2.137257e-05  0.000984
# 23384.615385  1.725612e-05  0.000988
# 24615.384615  1.393251e-05  0.000991
# 25846.153846  1.124904e-05  0.000994
# 27076.923077  9.082426e-06  0.000996
# 28307.692308  7.333107e-06  0.000998
# 29538.461538  5.920717e-06  0.000999
# 30769.230769  4.780360e-06  0.001001
# 32000.000000  3.859640e-06  0.001001
# 33230.769231  3.116256e-06  0.001002
# 34461.538462  2.516050e-06  0.001003
# 35692.307692  2.031447e-06  0.001003
# 36923.076923  1.640181e-06  0.001004
# 38153.846154  1.324274e-06  0.001004
# 39384.615385  1.069213e-06  0.001004
# 40615.384615  8.632778e-07  0.001004
# 41846.153846  6.970060e-07  0.001005
# 43076.923077  5.627555e-07  0.001005
# 44307.692308  4.543648e-07  0.001005
# 45538.461538  3.668547e-07  0.001005
# 46769.230769  2.961986e-07  0.001005
# 48000.000000  2.391504e-07  0.001005
#                                  parameter  \
# 0                          simulation_path
# 1   singlet_oxygen_diffusion_distance (nm)
# 2                          oxidation_angle
# 3                                root_path
# 4                                   medium
# 5              photosensitizer_mg_per_disc
# 6                             cm2_per_disc
# 7                       surface_area (m^2)
# 8            photosensitizer_mg_per_sqr_cm
# 9                         bacterial_specie
# 10               photosensitizer_selection
# 11                               soret (m)
# 12                                   q (m)
# 13                        atomic_thickness
# 14                   solution_volume (m^3)
# 15                   photosensitizer_molar
# 16                            visible (nm)
# 17                      visible_proportion
# 18                                   watts
# 19                            initial_time
# 20                          total_time (s)
# 21                            timestep (s)
#
#                                                                                                                                                   value
# 0   C:\Users\Andrew Freiburger\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PDIpy\PDIpy\examples\2021-12-10-PDIpy-A3B_4Zn-Saureus-1
# 1                                                                                                                                              0.000000
# 2                                                                                                                                                     5
# 3                                         C:\Users\Andrew Freiburger\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PDIpy\PDIpy\pdipy
# 4                                                                                                                                                 water
# 5                                                                                                                                              0.300000
# 6                                                                                                                                              1.911345
# 7                                                                                                                                              0.000191
# 8                                                                                                                                              0.156958
# 9                                                                                                                                               Saureus
# 10                                                                                                                                              A3B_4Zn
# 11                                                                                                  {'upper': 4.3e-07, 'lower': 4.0000000000000003e-07}
# 12                                                                                                                {'upper': 6.25e-07, 'lower': 5.3e-07}
# 13                                                                                                                                             0.000000
# 14                                                                                                                                             0.000000
# 15                                                                                                                                           338.280051
# 16                                                                                                                 {'upper': 7.8e-07, 'lower': 3.9e-07}
# 17                                                                                                                                             0.500000
# 18                                                                                                                                          2968.206307
# 19                                                                                                                                                    0
# 20                                                                                                                                         48000.000000
# 21                                                                                                                                          1200.000000
#                      variable  \
# 0             simulation_path
# 1     center_porphyrin_length
# 2               sp2_extension
# 3               sp3_diazirine
# 4        linked_sp3_diazirine
# 5            photosensitizers
# 6      molecular_volume (m^3)
# 7           volume_proportion
# 8             area_proportion
# 9     photon_moles_per_second
# 10  photon_moles_per_timestep
# 11         dissolved_mo_molar
# 12            e_ps_calculated
# 13                      so_qy
# 14          so_decay_time (s)
# 15           so_rise_time (s)
# 16   e_ps_charge_transfer (s)
# 17        e_ps_decay_time (s)
# 18          ps_excitation (s)
# 19          hv_photobleaching
# 20                fa_g/L_conc
# 21                   fa_molar
# 22                       k_fa
#
#                                                                                                                                                   value
# 0   C:\Users\Andrew Freiburger\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PDIpy\PDIpy\examples\2021-12-10-PDIpy-A3B_4Zn-Saureus-1
# 1                                                                                                                                              0.000000
# 2                                                                                                                                              0.000000
# 3                                                                                                                                              0.000000
# 4                                                                                                                                              0.000000
# 5                                                                                                                             122178730604427696.000000
# 6                                                                                                                                              0.000000
# 7                                                                                                                                            236.301736
# 8                                                                                                                                           3458.115578
# 9                                                                                                                                              0.003521
# 10                                                                                                                                             4.225720
# 11                                                                                                                                             0.000000
# 12                                                                                                                                           338.280051
# 13                                                                                                                                             0.480000
# 14                                                                                                                                             0.000010
# 15                                                                                                                                             0.000002
# 16                                                                                                                                             0.000001
# 17                                                                                                                                             0.000000
# 18                                                                                                                                             0.000000
# 19                                                                                                                                             0.000270
# 20                                                                                                                                           911.526882
# 21                                                                                                                                             0.001005
# 22                                                                                                                                           618.206042

# %% [markdown]
# ## Processing the raw data

# %%
display(processed_data)

# target_reduction = (100-10**-1.76)/100
target_reduction = 0.975
for index, point in processed_data.iterrows():
    if index > 6:
        print(point['oxidation_proportion'])
    if point['oxidation_proportion'] >= target_reduction:
        print('time to target (hr): ', index)
        break
# display(raw_data)
# Out:
#            oxidation_proportion
# time (hr)
# 0.000000               0.000000
# 0.341880               0.192462
# 0.683761               0.347883
# 1.025641               0.473392
# 1.367521               0.574746
# 1.709402               0.656593
# 2.051282               0.722686
# 2.393162               0.776058
# 2.735043               0.819159
# 3.076923               0.853963
# 3.418803               0.882069
# 3.760684               0.904767
# 4.102564               0.923095
# 4.444444               0.937896
# 4.786325               0.949849
# 5.128205               0.959501
# 5.470085               0.967295
# 5.811966               0.973590
# 6.153846               0.978673
# 6.495726               0.982777
# 6.837607               0.986092
# 7.179487               0.988769
# 7.521368               0.990930
# 7.863248               0.992676
# 8.205128               0.994085
# 8.547009               0.995224
# 8.888889               0.996143
# 9.230769               0.996885
# 9.572650               0.997485
# 9.914530               0.997969
# 10.256410              0.998360
# 10.598291              0.998675
# 10.940171              0.998930
# 11.282051              0.999136
# 11.623932              0.999302
# 11.965812              0.999437
# 12.307692              0.999545
# 12.649573              0.999633
# 12.991453              0.999703
# 13.333333              0.999760
# 0.9786727403964135
# time to target (hr):  6.153846153846153
