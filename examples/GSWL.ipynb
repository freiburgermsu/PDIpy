# %% [markdown]
# # Define and execute the simulation

# %%
from scipy.constants import minute
import os
# %run ../pdipy/core.py

pdi = PDIBacterialPkg(verbose = True, jupyter = True)
pdi.define_system(surface_system = True)
pdi.define_bacterium(bacterial_specie = 'Saureus')
pdi.define_photosensitizer(photosensitizer = 'A3B_4Zn')
pdi.define_light(light_source = 'LED', lux = 26400,)
pdi.singlet_oxygen_calculations(timestep = 0.2, total_time = 10)
pdi.geometric_oxidation()
pdi.kinetic_calculation()
pdi.export()

# %matplotlib inline
# Out:
# The center porphyrin object is 6.1E-10 meters
# The benzyl extension is 6.1E-10 meters
# The diazirine is 7.2E-10 meters
# Solution depth is not calculated for surface systems
# The molecular length is 1.8E-9 meters
# The molecular volume is 5.0E-28 cubic meters
# The photosensitizer volume proportion is 2.8E1
# The photosensitizer area proportion is 9.4E2
# ('photons per timestep: ', 0.1627881519022508)
# ('molecular oxygen molecules: ', '2.8E-7')
# ('effective excitation watts: ', '3.2E3')
# ('oxidized volume proportion: ', 0.001902650954146388)
# ('volume:area consistency', True)
# // Created by libAntimony v2.12.0.3
# model *pdipy_oxidation()
#
#   // Compartments and Species:
#   species ps, e_ps, b_ps, mo, so, fa, ofa;
#
#   // Assignment Rules:
#   oxidation := ofa/(ofa + fa);
#
#   // Reactions:
#   _J0: ps -> e_ps; 20000000000000*ps - 666666666.666667*e_ps;
#   _J1: ps => b_ps; 0.000270211764705882*ps;
#   _J2: e_ps + mo -> so + ps; 0.48*2000000*e_ps*mo - 24998.1249531238*so;
#   _J3: so + fa => ofa + mo; 246112.258064516*so*fa;
#
#   // Species initializations:
#   ps = 0.00304891275402485;
#   e_ps = 91.4673826207454;
#   b_ps = 0.000494312593065887;
#   mo = 8.00488590428614e-11;
#   so = 2.81180498411479e-07;
#   fa = 2.69139969714409e-13;
#   ofa = 0.0010053172227679;
#
#   // Other declarations:
#   var oxidation;
# end
#
# ('\nCurrent integrator:', '\n', < roadrunner.Integrator() "cvode" 'relative_tolerance': 0.000001, 'absolute_tolerance': 0.000000000001, 'stiff': True, 'maximum_bdf_order': 5, 'maximum_adams_order': 12, 'maximum_num_steps': 20000, 'maximum_time_step': 0, 'minimum_time_step': 0, 'initial_time_step': 0, 'multiple_steps': False, 'variable_step_size': False, 'max_output_rows': 100000 >
# )
#                  [ps]     [e_ps]    [b_ps]          [mo]          [so]  \
# Time (s)
# 0.000000    91.470926   0.000000  0.000000  2.812605e-07  0.000000e+00
# 12.244898    0.003049  91.467867  0.000010  8.038786e-11  2.811802e-07
# 24.489796    0.003049  91.467857  0.000020  8.019390e-11  2.811804e-07
# 36.734694    0.003049  91.467847  0.000030  8.011079e-11  2.811804e-07
# 48.979592    0.003049  91.467837  0.000040  8.007518e-11  2.811805e-07
# 61.224490    0.003049  91.467826  0.000050  8.005992e-11  2.811805e-07
# 73.469388    0.003049  91.467816  0.000061  8.005339e-11  2.811805e-07
# 85.714286    0.003049  91.467806  0.000071  8.005059e-11  2.811805e-07
# 97.959184    0.003049  91.467796  0.000081  8.004940e-11  2.811805e-07
# 110.204082   0.003049  91.467786  0.000091  8.004889e-11  2.811805e-07
# 122.448980   0.003049  91.467776  0.000101  8.004868e-11  2.811805e-07
# 134.693878   0.003049  91.467766  0.000111  8.004859e-11  2.811805e-07
# 146.938776   0.003049  91.467756  0.000121  8.004856e-11  2.811805e-07
# 159.183673   0.003049  91.467746  0.000131  8.004855e-11  2.811805e-07
# 171.428571   0.003049  91.467736  0.000141  8.004856e-11  2.811805e-07
# 183.673469   0.003049  91.467726  0.000151  8.004856e-11  2.811805e-07
# 195.918367   0.003049  91.467716  0.000161  8.004857e-11  2.811805e-07
# 208.163265   0.003049  91.467705  0.000171  8.004858e-11  2.811805e-07
# 220.408163   0.003049  91.467695  0.000182  8.004859e-11  2.811805e-07
# 232.653061   0.003049  91.467685  0.000192  8.004859e-11  2.811805e-07
# 244.897959   0.003049  91.467675  0.000202  8.004860e-11  2.811805e-07
# 257.142857   0.003049  91.467665  0.000212  8.004861e-11  2.811805e-07
# 318.367347  9.567228e-13  0.001005
# 330.612245  6.353748e-13  0.001005
# 342.857143  3.592991e-13  0.001005
# 355.102041  1.030847e-13  0.001005
# 367.346939 -3.601789e-14  0.001005
# 379.591837 -2.612575e-13  0.001005
# 391.836735 -3.586905e-13  0.001005
# 404.081633 -6.727996e-13  0.001005
# 416.326531 -1.588803e-12  0.001005
# 428.571429 -2.468073e-12  0.001005
# 440.816327 -2.246308e-12  0.001005
# 453.061224 -1.987250e-12  0.001005
# 465.306122 -1.514656e-12  0.001005
# 477.551020 -6.977529e-13  0.001005
# 489.795918  1.728108e-13  0.001005
# 502.040816  5.291991e-13  0.001005
# 514.285714  1.038929e-12  0.001005
# 526.530612  1.552913e-12  0.001005
# 538.775510  1.576273e-12  0.001005
# 551.020408  1.195405e-12  0.001005
# 563.265306  1.087201e-12  0.001005
# 575.510204  8.643622e-13  0.001005
# 587.755102  5.089646e-13  0.001005
# 600.000000  2.691400e-13  0.001005
#                                  parameter  \
# 0                          simulation_path
# 1   singlet_oxygen_diffusion_distance (nm)
# 2                          oxidation_angle
# 3                                root_path
# 4                                   medium
# 5              photosensitizer_mg_per_disc
# 6                             cm2_per_disc
# 7                       surface_area (m^2)
# 8            photosensitizer_mg_per_sqr_cm
# 9                         bacterial_specie
# 10               photosensitizer_selection
# 11                               soret (m)
# 12                                   q (m)
# 13                        atomic_thickness
# 14                   solution_volume (m^3)
# 15                   photosensitizer_molar
# 16                            visible (nm)
# 17                      visible_proportion
# 18                                   watts
# 19                            initial_time
# 20                          total_time (s)
# 21                            timestep (s)
#
#                                                                                                                                                   value
# 0   C:\Users\Andrew Freiburger\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PDIpy\PDIpy\examples\2021-12-08-PDIpy-A3B_4Zn-Saureus-5
# 1                                                                                                                                              0.000000
# 2                                                                                                                                                     5
# 3                                         C:\Users\Andrew Freiburger\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PDIpy\PDIpy\pdipy
# 4                                                                                                                                                 water
# 5                                                                                                                                              0.300000
# 6                                                                                                                                              7.068583
# 7                                                                                                                                              0.000707
# 8                                                                                                                                              0.042441
# 9                                                                                                                                               Saureus
# 10                                                                                                                                              A3B_4Zn
# 11                                                                                                  {'upper': 4.3e-07, 'lower': 4.0000000000000003e-07}
# 12                                                                                                                {'upper': 6.25e-07, 'lower': 5.3e-07}
# 13                                                                                                                                             0.000000
# 14                                                                                                                                             0.000000
# 15                                                                                                                                            91.470926
# 16                                                                                                                 {'upper': 7.8e-07, 'lower': 3.9e-07}
# 17                                                                                                                                             0.500000
# 18                                                                                                                                         10977.094331
# 19                                                                                                                                                    0
# 20                                                                                                                                           600.000000
# 21                                                                                                                                            12.000000
#                           variable  \
# 0                  simulation_path
# 1          center_porphyrin_length
# 2                    sp2_extension
# 3                    sp3_diazirine
# 4             linked_sp3_diazirine
# 5                 photosensitizers
# 6           molecular_volume (m^3)
# 7                volume_proportion
# 8                  area_proportion
# 9          photon_moles_per_second
# 10       photon_moles_per_timestep
# 11              dissolved_mo_molar
# 12                   quantum_yield
# 13                         healing
# 14               so_decay_time (s)
# 15                so_rise_time (s)
# 16        e_ps_charge_transfer (s)
# 17             e_ps_decay_time (s)
# 18               ps_excitation (s)
# 19               hv_photobleaching
# 20                 cell_radius (m)
# 21  oxidized_membrane_volume_ratio
# 22             oxidized_area_ratio
# 23                     fa_g/L_conc
# 24                        fa_molar
# 25                            k_fa
#
#                                                                                                                                                   value
# 0   C:\Users\Andrew Freiburger\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PDIpy\PDIpy\examples\2021-12-08-PDIpy-A3B_4Zn-Saureus-5
# 1                                                                                                                                              0.000000
# 2                                                                                                                                              0.000000
# 3                                                                                                                                              0.000000
# 4                                                                                                                                              0.000000
# 5                                                                                                                             122178730604427696.000000
# 6                                                                                                                                              0.000000
# 7                                                                                                                                             27.734160
# 8                                                                                                                                            935.074452
# 9                                                                                                                                              0.013566
# 10                                                                                                                                             0.162788
# 11                                                                                                                                             0.000000
# 12                                                                                                                                             0.480000
# 13                                                                                                                                                    5
# 14                                                                                                                                             0.000040
# 15                                                                                                                                             0.000002
# 16                                                                                                                                             0.000001
# 17                                                                                                                                             0.000000
# 18                                                                                                                                             0.000000
# 19                                                                                                                                             0.000270
# 20                                                                                                                                             0.000620
# 21                                                                                                                                             0.001903
# 22                                                                                                                                             0.001903
# 23                                                                                                                                           911.526882
# 24                                                                                                                                             0.001005
# 25                                                                                                                                        246112.258065

# %% [markdown]
# # Surface biofilm system

# %%
from scipy.constants import minute
import os
# %run ../pdipy/core.py

pdi = PDIBacterialPkg(verbose = True, jupyter = True)
pdi.define_system(surface_system = True)
pdi.define_bacterium(bacterial_specie = 'Saureus')
pdi.define_photosensitizer(photosensitizer = 'A3B_4Zn')
pdi.define_light(light_source = 'LED', lux = 26400,)
pdi.singlet_oxygen_calculations(timestep = 20, total_time = 800)
pdi.cytoplasmic_membrane()
raw_data = pdi.kinetic_calculation()
processed_data = pdi.export(excitation_proportion = True)

# %matplotlib inline
# Out:
# 1.4172133351064733e-10
# 5.997473236245768e-13
# The tetrapyrrole is 6.1E-10 meters
# The benzyl extension is 6.1E-10 meters
# The diazirine is 7.2E-10 meters
# Solution depth is not calculated for surface systems
# The molecular length is 3.3E-9 meters
# The molecular volume is 1.2E-27 cubic meters
# The photosensitizer volume proportion is 2.4E2
# The photosensitizer area proportion is 3.5E3
# e_ps times greater than the photosensitizer molar 1.7710975704625804
# ('photons per timestep: ', 4.225719962339387)
# ('molecular oxygen molecules: ', '2.8E-7')
# ('effective excitation watts: ', '8.6E2')
# // Created by libAntimony v2.12.0.3
# model *pdipy_oxidation()
#
#   // Compartments and Species:
#   species ps, e_ps, b_ps, mo, so, fa, o_fa;
#
#   // Assignment Rules:
#   oxidation := o_fa/(o_fa + fa);
#
#   // Reactions:
#   _J0: ps -> e_ps; 20000000000000*ps - 666666666.666667*e_ps;
#   _J1: ps => b_ps; 0.000270211764705882*ps;
#   _J2: e_ps + mo -> so + ps; 0.48*2000000*e_ps*mo - 97087.0958345471*so;
#   _J3: so + fa => o_fa + mo; 618.206041660442*so*fa;
#
#   // Species initializations:
#   ps = 0.0112707521779258;
#   e_ps = 338.122565337774;
#   b_ps = 0.146215116011619;
#   mo = 8.40998191810324e-11;
#   so = 2.81176447451342e-07;
#   fa = 2.39150369583496e-07;
#   o_fa = 0.00100507807266746;
#
#   // Variable initializations:
#   o_eps = 0;
#
#   // Other declarations:
#   var oxidation;
#   const o_eps;
# end
#
# ('\nCurrent integrator:', '\n', < roadrunner.Integrator() "cvode" 'relative_tolerance': 0.000001, 'absolute_tolerance': 0.000000000001, 'stiff': True, 'maximum_bdf_order': 5, 'maximum_adams_order': 12, 'maximum_num_steps': 20000, 'maximum_time_step': 0, 'minimum_time_step': 0, 'initial_time_step': 0, 'multiple_steps': False, 'variable_step_size': False, 'max_output_rows': 100000 >
# 45538.461538    0.011271  338.130062  0.138718  8.409796e-11  2.811764e-07
# 46769.230769    0.011271  338.126314  0.142467  8.409889e-11  2.811764e-07
# 48000.000000    0.011271  338.122565  0.146215  8.409982e-11  2.811764e-07
#
#                       [fa]     [ofa]
# Time (s)
# 0.000000      1.005317e-03  0.000000
# 1230.769231   8.116910e-04  0.000194
# 2461.538462   6.553558e-04  0.000350
# 3692.307692   5.291310e-04  0.000476
# 4923.076923   4.272179e-04  0.000578
# 6153.846154   3.449338e-04  0.000660
# 7384.615385   2.784979e-04  0.000727
# 8615.384615   2.248579e-04  0.000780
# 9846.153846   1.815493e-04  0.000824
# 11076.923077  1.465820e-04  0.000859
# 12307.692308  1.183496e-04  0.000887
# 13538.461538  9.555495e-05  0.000910
# 14769.230769  7.715061e-05  0.000928
# 16000.000000  6.229106e-05  0.000943
# 17230.769231  5.029350e-05  0.000955
# 18461.538462  4.060674e-05  0.000965
# 19692.307692  3.278570e-05  0.000973
# 20923.076923  2.647102e-05  0.000979
# 22153.846154  2.137257e-05  0.000984
# 23384.615385  1.725612e-05  0.000988
# 24615.384615  1.393251e-05  0.000991
# 25846.153846  1.124904e-05  0.000994
# 27076.923077  9.082426e-06  0.000996
# 28307.692308  7.333107e-06  0.000998
# 29538.461538  5.920717e-06  0.000999
# 30769.230769  4.780360e-06  0.001001
# 32000.000000  3.859640e-06  0.001001
# 33230.769231  3.116256e-06  0.001002
# 34461.538462  2.516050e-06  0.001003
# 35692.307692  2.031447e-06  0.001003
# 36923.076923  1.640181e-06  0.001004
# 38153.846154  1.324274e-06  0.001004
# 39384.615385  1.069213e-06  0.001004
# 40615.384615  8.632778e-07  0.001004
# 41846.153846  6.970060e-07  0.001005
# 43076.923077  5.627555e-07  0.001005
# 44307.692308  4.543648e-07  0.001005
# 45538.461538  3.668547e-07  0.001005
# 46769.230769  2.961986e-07  0.001005
# 48000.000000  2.391504e-07  0.001005
#                                  parameter  \
# 0                          simulation_path
# 1   singlet_oxygen_diffusion_distance (nm)
# 2                          oxidation_angle
# 3                                root_path
# 4                                   medium
# 5              photosensitizer_mg_per_disc
# 6                             cm2_per_disc
# 7                       surface_area (m^2)
# 8            photosensitizer_mg_per_sqr_cm
# 9                         bacterial_specie
# 10               photosensitizer_selection
# 11                               soret (m)
# 12                                   q (m)
# 13                        atomic_thickness
# 14                   solution_volume (m^3)
# 15                   photosensitizer_molar
# 16                            visible (nm)
# 17                      visible_proportion
# 18                                   watts
# 19                            initial_time
# 20                          total_time (s)
# 21                            timestep (s)
#
#                                                                                                                                                   value
# 0   C:\Users\Andrew Freiburger\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PDIpy\PDIpy\examples\2021-12-10-PDIpy-A3B_4Zn-Saureus-1
# 1                                                                                                                                              0.000000
# 2                                                                                                                                                     5
# 3                                         C:\Users\Andrew Freiburger\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PDIpy\PDIpy\pdipy
# 4                                                                                                                                                 water
# 5                                                                                                                                              0.300000
# 6                                                                                                                                              1.911345
# 7                                                                                                                                              0.000191
# 8                                                                                                                                              0.156958
# 9                                                                                                                                               Saureus
# 10                                                                                                                                              A3B_4Zn
# 11                                                                                                  {'upper': 4.3e-07, 'lower': 4.0000000000000003e-07}
# 12                                                                                                                {'upper': 6.25e-07, 'lower': 5.3e-07}
# 13                                                                                                                                             0.000000
# 14                                                                                                                                             0.000000
# 15                                                                                                                                           338.280051
# 16                                                                                                                 {'upper': 7.8e-07, 'lower': 3.9e-07}
# 17                                                                                                                                             0.500000
# 18                                                                                                                                          2968.206307
# 19                                                                                                                                                    0
# 20                                                                                                                                         48000.000000
# 21                                                                                                                                          1200.000000
#                      variable  \
# 0             simulation_path
# 1     center_porphyrin_length
# 2               sp2_extension
# 3               sp3_diazirine
# 4        linked_sp3_diazirine
# 5            photosensitizers
# 6      molecular_volume (m^3)
# 7           volume_proportion
# 8             area_proportion
# 9     photon_moles_per_second
# 10  photon_moles_per_timestep
# 11         dissolved_mo_molar
# 12            e_ps_calculated
# 13                      so_qy
# 14          so_decay_time (s)
# 15           so_rise_time (s)
# 16   e_ps_charge_transfer (s)
# 17        e_ps_decay_time (s)
# 18          ps_excitation (s)
# 19          hv_photobleaching
# 20                fa_g/L_conc
# 21                   fa_molar
# 22                       k_fa
#
#                                                                                                                                                   value
# 0   C:\Users\Andrew Freiburger\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PDIpy\PDIpy\examples\2021-12-10-PDIpy-A3B_4Zn-Saureus-1
# 1                                                                                                                                              0.000000
# 2                                                                                                                                              0.000000
# 3                                                                                                                                              0.000000
# 4                                                                                                                                              0.000000
# 5                                                                                                                             122178730604427696.000000
# 6                                                                                                                                              0.000000
# 7                                                                                                                                            236.301736
# 8                                                                                                                                           3458.115578
# 9                                                                                                                                              0.003521
# 10                                                                                                                                             4.225720
# 11                                                                                                                                             0.000000
# 12                                                                                                                                           338.280051
# 13                                                                                                                                             0.480000
# 14                                                                                                                                             0.000010
# 15                                                                                                                                             0.000002
# 16                                                                                                                                             0.000001
# 17                                                                                                                                             0.000000
# 18                                                                                                                                             0.000000
# 19                                                                                                                                             0.000270
# 20                                                                                                                                           911.526882
# 21                                                                                                                                             0.001005
# 22                                                                                                                                           618.206042

# %% [markdown]
# ## Processing the raw data

# %%
display(processed_data)

# target_reduction = (100-10**-1.76)/100
target_reduction = 0.975
for index, point in processed_data.iterrows():
    if index > 6:
        print(point['oxidation_proportion'])
    if point['oxidation_proportion'] >= target_reduction:
        print('time to target (hr): ', index)
        break
# display(raw_data)
# Out:
#            oxidation_proportion
# time (hr)
# 0.000000               0.000000
# 0.341880               0.192462
# 0.683761               0.347883
# 1.025641               0.473392
# 1.367521               0.574746
# 1.709402               0.656593
# 2.051282               0.722686
# 2.393162               0.776058
# 2.735043               0.819159
# 3.076923               0.853963
# 3.418803               0.882069
# 3.760684               0.904767
# 4.102564               0.923095
# 4.444444               0.937896
# 4.786325               0.949849
# 5.128205               0.959501
# 5.470085               0.967295
# 5.811966               0.973590
# 6.153846               0.978673
# 6.495726               0.982777
# 6.837607               0.986092
# 7.179487               0.988769
# 7.521368               0.990930
# 7.863248               0.992676
# 8.205128               0.994085
# 8.547009               0.995224
# 8.888889               0.996143
# 9.230769               0.996885
# 9.572650               0.997485
# 9.914530               0.997969
# 10.256410              0.998360
# 10.598291              0.998675
# 10.940171              0.998930
# 11.282051              0.999136
# 11.623932              0.999302
# 11.965812              0.999437
# 12.307692              0.999545
# 12.649573              0.999633
# 12.991453              0.999703
# 13.333333              0.999760
# 0.9786727403964135
# time to target (hr):  6.153846153846153
